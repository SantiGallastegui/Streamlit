# %%
import pandas as pd
import requests

ETH = requests.get('https://ftx.com/api/markets/ETH/USD/candles?resolution=86400&start_time=30000000').json()

# %%
historical.prin
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 print(historical.to_string)
#
# AttributeError: 'dict' object has no attribute 'to_string'

# %%
def filtros(var):
    df = var
    df = pd.DataFrame(df['result'])
    df.drop(['startTime'], axis = 1 , inplace = True)
    df['time'] = pd.to_datetime(df['time'], unit='ms')
    df.set_index('time', inplace=True)
    vnames= [name for name in locals() if locals()[name] is df ]
    print(vnames[0])
    df['Cripto']= df[0]
    df['20 SMA'] = df.close.rolling(20).mean()

# %%
filtros(ETH)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [53], line 1
# ----> 1 filtros(ETH)
#
# Cell In [52], line 7, in filtros(critomoneda)
#       5 df['time'] = pd.to_datetime(df['time'], unit='ms')
#       6 df.set_index('time', inplace=True)
# ----> 7 vnames= [name for name in locals() if locals()[name] is df ]
#       8 print(vnames[0])
#       9 df['Cripto']= df[0]
#
# Cell In [52], line 7, in <listcomp>(.0)
#       5 df['time'] = pd.to_datetime(df['time'], unit='ms')
#       6 df.set_index('time', inplace=True)
# ----> 7 vnames= [name for name in locals() if locals()[name] is df ]
#       8 print(vnames[0])
#       9 df['Cripto']= df[0]
#
# KeyError: 'critomoneda'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [49], line 1
# ----> 1 critomoneda
#
# NameError: name 'critomoneda' is not defined

# %%
variable = 22
vnames = [name for name in globals() if globals()[name] is variable]
print(vnames[0])
# Out:
# variable

# %%
ETH_USD = pd.DataFrame(historical['result'])
ETH_USD.drop(['startTime'], axis = 1 , inplace = True)
ETH_USD['time'] = pd.to_datetime(ETH_USD['time'], unit='ms')
ETH_USD.set_index('time', inplace=True)
ETH_USD['20 SMA'] = ETH_USD.close.rolling(20).mean()

# %%
ETH_USD.tail()
# Out:
#               open    high     low   close        volume    20 SMA
# time
# 2022-09-24  1327.0  1349.6  1304.7  1317.0  2.910534e+08  1512.905
# 2022-09-25  1317.0  1336.9  1269.4  1294.4  3.798832e+08  1496.725
# 2022-09-26  1294.4  1340.5  1278.2  1336.6  7.221542e+08  1485.610
# 2022-09-27  1336.6  1400.4  1303.8  1328.2  5.980146e+08  1470.515
# 2022-09-28  1328.2  1340.2  1254.0  1327.6  5.771414e+08  1455.095

# %%
ETH_USD['Cripto']= "ETH"

# %%
ETH_USD
# Out:
#                 open     high      low    close        volume    20 SMA Cripto
# time
# 2019-09-14   181.565   189.19   180.39   188.76  8.682133e+03       NaN    ETH
# 2019-09-15   188.760   190.86   186.21   189.26  0.000000e+00       NaN    ETH
# 2019-09-16   189.260   199.39   188.37   197.70  4.911637e+04       NaN    ETH
# 2019-09-17   197.710   215.06   196.20   207.93  1.359913e+05       NaN    ETH
# 2019-09-18   207.830   217.12   207.76   210.11  1.634503e+05       NaN    ETH
# ...              ...      ...      ...      ...           ...       ...    ...
# 2022-09-24  1327.000  1349.60  1304.70  1317.00  2.910534e+08  1512.905    ETH
# 2022-09-25  1317.000  1336.90  1269.40  1294.40  3.798832e+08  1496.725    ETH
# 2022-09-26  1294.400  1340.50  1278.20  1336.60  7.221542e+08  1485.610    ETH
# 2022-09-27  1336.600  1400.40  1303.80  1328.20  5.980146e+08  1470.515    ETH
# 2022-09-28  1328.200  1340.20  1254.00  1327.60  5.771414e+08  1455.095    ETH
#
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[go.Candlestick(x = ETH_USD.index,
                                    open = ETH_USD['open'],
                                    high = ETH_USD['high'],
                                    low = ETH_USD['low'],
                                    close = ETH_USD['close'],
                                    ),
                     go.Scatter(x=ETH_USD.index, y=ETH_USD['20 SMA'], line=dict(color='purple', width=1))])


fig.show()
